# %% [markdown]
# # Content

# %% [markdown]
# # Prepping

# %% [markdown]
# ## Drive location

# %% [markdown]
# Followed cells are written to install `FinRL` which are adjusted for Vietnam stock market by our group

# %%
# %mkdir CS106-Vietnam-Stock-Trading

# %%
# %cd CS106-Vietnam-Stock-Trading

# %%
# !sudo apt-get update && sudo apt-get install cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx

# %% [markdown]
# `!pip install` below has already install `vnquant` repo in it

# %%
# !pip install git+https://github.com/ThangDuong59/CS106-Vietnam-Stock-Trading.git

# %% [markdown]
# ## Essential modules

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
import datetime
import itertools

# %matplotlib inline
from pprint import pprint

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# # A. Problem definition

# %% [markdown]
# This problem is to design an automated trading solution for single/multiple stock trading. We model the stock trading process as a **Markov Decision Process (MDP)**. We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * ***Action:*** The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: $a ∈ {−1, 0, 1}$, where $−1, 0, 1$ represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space ${−k, ..., −1, 0, 1, ..., k}$, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * ***Reward function:*** `r(s, a, s′)` is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., $r(s, a, s′) = v′ − v$, where $v'$ and $v$ represent the portfolio
# values at state s′ and s, respectively
#
# * ***State:*** The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * ***Environment:*** VN30 for multiple stock and VNM for single stock
#
# The data is provided through [**vnquant**](https://github.com/ThangDuong59/vnquant) which is adjusted by us for suitable to FinRL
#
# And this repo is based on [**FinRL: A Deep Reinforcement Learning Framework for Quantitative Finance**](https://github.com/AI4Finance-LLC/FinRL#finrl-a-deep-reinforcement-learning-framework-for-quantitative-finance----)

# %%
from finrl.config import config
from finrl.marketdata.yahoodownloader import YahooDownloader
from finrl.marketdata.vnquantdownloader import vnquantDownloader
from finrl.preprocessing.preprocessors import FeatureEngineer
from finrl.preprocessing.data import data_split
from finrl.model.models import DRLAgent, DRLEnsembleAgent
from finrl.env.env_stocktrading import StockTradingEnv
from finrl.trade.backtest import backtest_stats, backtest_plot, get_daily_return, get_baseline

# %% [markdown]
# ## Data

# %% [markdown]
# `vnquant`, written by Pham Dinh Khanh, is a package allow you to crawl data through **VNDIRECT** API.
#
# The reason we don't use default crawler is **Yahoo Downloader** is just able to download some common stock in Vietnam.

# %% [markdown]
# -----
# class vnquantDownloader:
#     Provides methods for retrieving daily stock data from
#     VNDirect
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from VNDirect API
#         Returns
#         -------
#         `pd.DataFrame`
#             7 columns: A date, open, high, low, close, volume and tick symbol
#             for the specified stock ticker
#         """

# %%
config.VN_30_TICKER
# Out:
# ['BID',
#  'BVH',
#  'CTG',
#  'FPT',
#  'GAS',
#  'HDB',
#  'HPG',
#  'KDH',
#  'MBB',
#  'MSN',
#  'MWG',
#  'NVL',
#  'PDR',
#  'PLX',
#  'PNJ',
#  'POW',
#  'REE',
#  'SBT',
#  'SSI',
#  'STB',
#  'TCB',
#  'VCB',
#  'VHM',
#  'VIC',
#  'VJC',
#  'VNM',
#  'VPB',
#  'VRE']

# %%
ticker = "VNM"#@param{type:"string"}
type(ticker)
config.SINGLE_TICKER = [ticker]
config.SINGLE_TICKER
# Out:
# ['VCB']

# %%
config.START_DATE = '2013-01-02' #@param {type:"date"}
config.START_TRADE_DATE = "2021-07-01" #@param {type:"date"}
config.END_DATE = "2019-01-01" #@param {type:"date"}

# %% [markdown]
# Users can choose their own ticker

# %%
ticker_list = config.VN_30_TICKER #@param ["config.VN_30_TICKER", "config.SINGLE_TICKER"] {type:"raw", allow-input: true}
df = vnquantDownloader(start_date=config.START_DATE,
                        end_date=config.END_DATE,
                        ticker_list=ticker_list, ).fetch_data()

# %%
df.tail(20)
# Out:
#              date      open      high       low     close      volume  tic  day
# 41883  2021-07-01   43400.0   43700.0   42750.0   32185.0  25460700.0  MBB    3
# 41884  2021-07-01  111400.0  114000.0  110100.0  113500.0   1706400.0  MSN    3
# 41885  2021-07-01  152000.0  152500.0  150500.0  151100.0    917200.0  MWG    3
# 41886  2021-07-01  123100.0  123600.0  119200.0  120000.0   6497433.0  NVL    3
# 41887  2021-07-01   93300.0   96200.0   92900.0   95900.0   5189800.0  PDR    3
# 41888  2021-07-01   54900.0   56000.0   54000.0   55500.0   2307300.0  PLX    3
# 41889  2021-07-01  100700.0  101200.0   99500.0  100200.0    362600.0  PNJ    3
# 41890  2021-07-01   12050.0   12150.0   11950.0   12100.0   7807900.0  POW    3
# 41891  2021-07-01   57500.0   58400.0   57300.0   57600.0    434400.0  REE    3
# 41892  2021-07-01   20800.0   21500.0   20800.0   21350.0   3495900.0  SBT    3
# 41893  2021-07-01   56000.0   58200.0   55400.0   57500.0  13724500.0  SSI    3
# 41894  2021-07-01   30600.0   31250.0   30450.0   31000.0  29657500.0  STB    3
# 41895  2021-07-01   52900.0   53500.0   52100.0   53300.0  19356700.0  TCB    3
# 41896  2021-07-01  116700.0  116800.0  115000.0  116400.0   2056400.0  VCB    3
# 41897  2021-07-01  117100.0  118500.0  116800.0  117200.0   3720200.0  VHM    3
# 41898  2021-07-01  119700.0  119900.0  118500.0  118600.0   2194700.0  VIC    3
# 41899  2021-07-01  121500.0  121500.0  119600.0  120700.0    534300.0  VJC    3
# 41900  2021-07-01   90600.0   91300.0   90400.0   90900.0   3841500.0  VNM    3
# 41901  2021-07-01   68200.0   70500.0   67600.0   70400.0  30962800.0  VPB    3
# 41902  2021-07-01   32000.0   32200.0   31650.0   31800.0   3093100.0  VRE    3

# %% [markdown]
# ### Download data

# %% [markdown]
# Save data to `.csv` file

# %%
now = datetime.datetime.now().strftime("%Y%m%d-%Hh%M")
df.to_csv("./" + config.DATA_SAVE_DIR + "/" + now + ".csv")

# %% [markdown]
# ## Data adjustment

# %% [markdown]
# -----
# class FeatureEngineer:
#     Provides methods for preprocessing the stock price data
#
#     Attributes
#     ----------
#         use_technical_indicator : boolean
#             we technical indicator or not
#         tech_indicator_list : list
#             a list of technical indicator names (modified from config.py)
#         use_turbulence : boolean
#             use turbulence index or not
#         user_defined_feature:boolean
#             user user defined features or not
#
#     Methods
#     -------
#     preprocess_data()
#         main method to do the feature engineering

# %%
# Using technical indicators, check https://pypi.org/project/stockstats/ for different names
config.TECHNICAL_INDICATORS_LIST
# Out:
# ['macd', 'rsi_30', 'cci_30', 'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                    tech_indicator_list = config.TECHNICAL_INDICATORS_LIST,
                    use_turbulence=True,
                    user_defined_feature = False)

# %%
processed = fe.preprocess_data(df)

list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(
    processed['date'].min(), processed['date'].max()).astype(str))
combination = list(itertools.product(list_date, list_ticker))

processed_full = pd.DataFrame(combination, columns=["date", "tic"]).merge(
    processed, on=["date", "tic"], how="left")
processed_full = processed_full[processed_full['date'].isin(
    processed['date'])]
processed_full = processed_full.sort_values(['date', 'tic'])

processed_full = processed_full.fillna(0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed_full.sample(n = 20)

# %%
train = data_split(processed_full, config.START_DATE,
                    config.START_TRADE_DATE)
trade = data_split(
    processed_full, config.START_TRADE_DATE, config.END_DATE)

# %%
stock_dimension = len(train.tic.unique())
state_space = (
    1
    + 2 * stock_dimension
    + len(config.TECHNICAL_INDICATORS_LIST) * stock_dimension
)

# %%
stock_dimension, state_space
# Out:
# (1, 7)

# %% [markdown]
# # B. Implementation

# %% [markdown]
# ## Env initial params

# %%
env_kwargs = {
        "hmax": 50000, 
        "initial_amount": 100000000,
        "buy_cost_pct": 0.0015,
        "sell_cost_pct": 0.0015,
        "state_space": state_space,
        "stock_dim": stock_dimension,
        "tech_indicator_list": config.TECHNICAL_INDICATORS_LIST,
        "action_space": stock_dimension,
        "reward_scaling": 1e-4
    }

# %% [markdown]
# ## Env initialization

# %%
e_train_gym = StockTradingEnv(df=train, **env_kwargs)
env_train, _ = e_train_gym.get_sb_env()

agent = DRLAgent(env=env_train)

# %% [markdown]
# ## Model training

# %% [markdown]
# ### SAC model

# %%
print("==============Model Training===========")
now = datetime.datetime.now().strftime("%Y%m%d-%Hh%M")

model_sac = agent.get_model("sac")
trained_sac = agent.train_model(
    model=model_sac, tb_log_name="sac", total_timesteps=100000
)

# %% [markdown]
# ### A2C model

# %%
print("==============Model Training===========")
now = datetime.datetime.now().strftime("%Y%m%d-%Hh%M")

model_a2c = agent.get_model("a2c")
trained_a2c = agent.train_model(
    model=model_a2c, tb_log_name="a2c", total_timesteps=100000
)
# Out:
# ==============Model Training===========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -99.7    |
# |    std                | 1        |
# |    value_loss         | 8.95e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 11.4     |
# |    std                | 1        |
# |    value_loss         | 5.63e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 3.52e-06 |
# |    std                | 1        |
# |    value_loss         | 8.85e-12 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 286      |
# |    iterations         | 400      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0191  |
# |    std                | 1.01     |
# |    value_loss         | 0.000311 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 297      |
# |    iterations         | 500      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -36.9    |
# |    std                | 1.02     |
# |    value_loss         | 1.65e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 304      |
# |    iterations         | 600      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.000722 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 602      |
# |    std                | 1.01     |
# |    value_loss         | 1.48e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 310       |
# |    iterations         | 700       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | -0.000369 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -37.1     |
# |    std                | 1         |
# |    value_loss         | 659       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 800      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -53      |
# |    std                | 1.01     |
# |    value_loss         | 2.12e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 318       |
# |    iterations         | 900       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -0.000338 |
# |    std                | 1.02      |
# |    value_loss         | 1.27e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 1000     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 236      |
# |    std                | 1.02     |
# |    value_loss         | 4.54e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 1100     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.46    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 562      |
# |    std                | 1.04     |
# |    value_loss         | 1.49e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 326      |
# |    iterations         | 1200     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.47    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.000174 |
# |    std                | 1.05     |
# |    value_loss         | 2.14e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 328      |
# |    iterations         | 1300     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 2.54e-07 |
# |    std                | 1.08     |
# |    value_loss         | 4.73e-15 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 329      |
# |    iterations         | 1400     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 5.76e-08 |
# |    std                | 1.09     |
# |    value_loss         | 1.12e-14 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 1500      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -1.54     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -2.99e-08 |
# |    std                | 1.13      |
# |    value_loss         | 1.68e-16  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 331       |
# |    iterations         | 1600      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -1.59     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -3.43e-08 |
# |    std                | 1.18      |
# |    value_loss         | 1.05e-16  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 1700     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -1.62    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.00446 |
# |    std                | 1.23     |
# |    value_loss         | 8.68e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 332       |
# |    iterations         | 1800      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -1.62     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -160      |
# |    std                | 1.23      |
# |    value_loss         | 2.25e+04  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 333      |
# |    iterations         | 1900     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -1.64    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.00213  |
# |    std                | 1.25     |
# |    value_loss         | 1.68e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 333      |
# |    iterations         | 2000     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.65    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0174  |
# |    std                | 1.27     |
# |    value_loss         | 0.000234 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 334       |
# |    iterations         | 2100      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -1.66     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -0.000271 |
# |    std                | 1.28      |
# |    value_loss         | 5.76e-08  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 334      |
# |    iterations         | 2200     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.66    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -13.6    |
# |    std                | 1.27     |
# |    value_loss         | 4.6e+03  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 334      |
# |    iterations         | 2300     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.65    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 68.4     |
# |    std                | 1.26     |
# |    value_loss         | 6.72e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 334      |
# |    iterations         | 2400     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.66    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.000862 |
# |    std                | 1.27     |
# |    value_loss         | 5.72e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 2500     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -1.68    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.000461 |
# |    std                | 1.29     |
# |    value_loss         | 9.67e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 2600     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -1.69    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 1.25e-05 |
# |    std                | 1.32     |
# |    value_loss         | 6.97e-11 |
# ------------------------------------
# day: 1493, episode: 10
# begin_total_asset: 100000000.00
# end_total_asset: 86744507.75
# total_reward: -13255492.25
# total_cost: 1573592.25
# total_trades: 14
# Sharpe: -0.182
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 2700     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -1.7     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.000501 |
# |    std                | 1.33     |
# |    value_loss         | 1.43e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 336       |
# |    iterations         | 2800      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -1.7      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 0.0113    |
# |    std                | 1.32      |
# |    value_loss         | 3.44e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 336      |
# |    iterations         | 2900     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -1.7     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 1.24e+03 |
# |    std                | 1.33     |
# |    value_loss         | 4.63e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 336       |
# |    iterations         | 3000      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -1.71     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -0.000508 |
# |    std                | 1.34      |
# |    value_loss         | 1.7e-07   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 336      |
# |    iterations         | 3100     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -1.74    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.00466 |
# |    std                | 1.38     |
# |    value_loss         | 9.36e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 336       |
# |    iterations         | 3200      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -1.76     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | 0.00778   |
# |    std                | 1.41      |
# |    value_loss         | 1.86e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 3300     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.000978 |
# |    std                | 1.41     |
# |    value_loss         | 4.75e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 337       |
# |    iterations         | 3400      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -1.78     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -0.000353 |
# |    std                | 1.44      |
# |    value_loss         | 4.9e-08   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 3500     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.00257  |
# |    std                | 1.44     |
# |    value_loss         | 3.98e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 338      |
# |    iterations         | 3600     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.00081  |
# |    std                | 1.45     |
# |    value_loss         | 3.13e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 338       |
# |    iterations         | 3700      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -1.81     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -84.2     |
# |    std                | 1.47      |
# |    value_loss         | 8.18e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 339      |
# |    iterations         | 3800     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -1.82    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.000504 |
# |    std                | 1.49     |
# |    value_loss         | 9.65e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 339      |
# |    iterations         | 3900     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -1.84    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.00377 |
# |    std                | 1.53     |
# |    value_loss         | 4.72e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 339      |
# |    iterations         | 4000     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.86    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00104 |
# |    std                | 1.55     |
# |    value_loss         | 3.5e-07  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 340      |
# |    iterations         | 4100     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -1.86    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0137  |
# |    std                | 1.56     |
# |    value_loss         | 9.76e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 340      |
# |    iterations         | 4200     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -1.86    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0155  |
# |    std                | 1.55     |
# |    value_loss         | 7.73e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 340      |
# |    iterations         | 4300     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -1.87    |
# |    explained_variance | -0.00824 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -14.5    |
# |    std                | 1.56     |
# |    value_loss         | 97.8     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 341      |
# |    iterations         | 4400     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.88    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -281     |
# |    std                | 1.58     |
# |    value_loss         | 3.9e+04  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 341      |
# |    iterations         | 4500     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -1.88    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.00637  |
# |    std                | 1.59     |
# |    value_loss         | 1.64e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 341       |
# |    iterations         | 4600      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -1.88     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -0.000201 |
# |    std                | 1.58      |
# |    value_loss         | 1.63e-08  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 341      |
# |    iterations         | 4700     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -1.89    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.0155   |
# |    std                | 1.59     |
# |    value_loss         | 0.00012  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 342      |
# |    iterations         | 4800     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.89    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.00302  |
# |    std                | 1.6      |
# |    value_loss         | 5.1e-06  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 342      |
# |    iterations         | 4900     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -1.9     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.00525  |
# |    std                | 1.62     |
# |    value_loss         | 1.24e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 342      |
# |    iterations         | 5000     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -1.9     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 484      |
# |    std                | 1.62     |
# |    value_loss         | 6.94e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 342      |
# |    iterations         | 5100     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -1.91    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.00501  |
# |    std                | 1.63     |
# |    value_loss         | 9.59e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 342      |
# |    iterations         | 5200     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -1.91    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.000741 |
# |    std                | 1.64     |
# |    value_loss         | 2.2e-07  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 342      |
# |    iterations         | 5300     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -1.93    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.00778 |
# |    std                | 1.67     |
# |    value_loss         | 2.96e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 5400     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -1.94    |
# |    explained_variance | 0.00331  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 76.8     |
# |    std                | 1.68     |
# |    value_loss         | 9.46e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 5500     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -1.94    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -160     |
# |    std                | 1.68     |
# |    value_loss         | 7.45e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 5600     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.94    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.014    |
# |    std                | 1.69     |
# |    value_loss         | 4.42e-05 |
# ------------------------------------
# day: 1493, episode: 20
# begin_total_asset: 100000000.00
# end_total_asset: 151182572.00
# total_reward: 51182572.00
# total_cost: 8073228.00
# total_trades: 43
# Sharpe: 0.638
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 5700     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -1.95    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.000434 |
# |    std                | 1.7      |
# |    value_loss         | 5.04e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 5800     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -1.95    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 203      |
# |    std                | 1.7      |
# |    value_loss         | 6.65e+04 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 5900      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -1.96     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -0.000173 |
# |    std                | 1.72      |
# |    value_loss         | 1.07e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 6000      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -1.97     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -0.0239   |
# |    std                | 1.73      |
# |    value_loss         | 0.00013   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 6100     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -1.98    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 162      |
# |    std                | 1.75     |
# |    value_loss         | 2.32e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 6200     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -1.98    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.0068   |
# |    std                | 1.75     |
# |    value_loss         | 1.06e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 6300     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -1.99    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.0101  |
# |    std                | 1.77     |
# |    value_loss         | 4.37e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 6400     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -2.01    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.00101 |
# |    std                | 1.8      |
# |    value_loss         | 3.75e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 6500     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -2.03    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 7.15e-05 |
# |    std                | 1.84     |
# |    value_loss         | 1.63e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 6600     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -2.03    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 294      |
# |    std                | 1.85     |
# |    value_loss         | 2.31e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 6700     |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -2.04    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.000488 |
# |    std                | 1.87     |
# |    value_loss         | 5.7e-08  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 6800     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -2.07    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.00273 |
# |    std                | 1.92     |
# |    value_loss         | 3.19e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 6900     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -2.1     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.00333 |
# |    std                | 1.97     |
# |    value_loss         | 4.55e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 7000     |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -2.09    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.0181  |
# |    std                | 1.96     |
# |    value_loss         | 8.59e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 7100      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -2.11     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -0.000551 |
# |    std                | 2         |
# |    value_loss         | 7.3e-08   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 7200      |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -2.13     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -3.01e-05 |
# |    std                | 2.03      |
# |    value_loss         | 2.46e-10  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 7300      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -2.14     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | 0.000978  |
# |    std                | 2.06      |
# |    value_loss         | 2.67e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 7400     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -2.16    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.0144   |
# |    std                | 2.1      |
# |    value_loss         | 3.35e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 7500      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -2.16     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | 0.016     |
# |    std                | 2.1       |
# |    value_loss         | 0.000112  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 7600     |
# |    time_elapsed       | 110      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -2.18    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.024   |
# |    std                | 2.15     |
# |    value_loss         | 0.000109 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 7700     |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | 0.00137  |
# |    std                | 2.18     |
# |    value_loss         | 6.44e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 7800     |
# |    time_elapsed       | 113      |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | 0.000127 |
# |    std                | 2.18     |
# |    value_loss         | 4.32e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 7900     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -2.22    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | -794     |
# |    std                | 2.22     |
# |    value_loss         | 1.1e+05  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 8000     |
# |    time_elapsed       | 116      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -2.23    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | 0.000126 |
# |    std                | 2.25     |
# |    value_loss         | 4.86e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 8100     |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -2.24    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | 0.000615 |
# |    std                | 2.27     |
# |    value_loss         | 9.06e-08 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 8200      |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -2.25     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8199      |
# |    policy_loss        | 0.00105   |
# |    std                | 2.31      |
# |    value_loss         | 3.13e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 8300     |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -2.28    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | 6.02e-08 |
# |    std                | 2.36     |
# |    value_loss         | 2.22e-16 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 8400      |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -2.3      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | -992      |
# |    std                | 2.41      |
# |    value_loss         | 2.59e+05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 8500     |
# |    time_elapsed       | 123      |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -2.3     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | -198     |
# |    std                | 2.41     |
# |    value_loss         | 2.21e+04 |
# ...
# |    value_loss         | 4.51e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 17300    |
# |    time_elapsed       | 249      |
# |    total_timesteps    | 86500    |
# | train/                |          |
# |    entropy_loss       | -2.98    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17299    |
# |    policy_loss        | 0.0801   |
# |    std                | 4.79     |
# |    value_loss         | 0.000813 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 17400    |
# |    time_elapsed       | 250      |
# |    total_timesteps    | 87000    |
# | train/                |          |
# |    entropy_loss       | -3       |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17399    |
# |    policy_loss        | -313     |
# |    std                | 4.88     |
# |    value_loss         | 1.96e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 17500    |
# |    time_elapsed       | 251      |
# |    total_timesteps    | 87500    |
# | train/                |          |
# |    entropy_loss       | -3       |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17499    |
# |    policy_loss        | 0.0215   |
# |    std                | 4.84     |
# |    value_loss         | 5.04e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 17600    |
# |    time_elapsed       | 253      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -3       |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17599    |
# |    policy_loss        | 0.00838  |
# |    std                | 4.85     |
# |    value_loss         | 1.04e-05 |
# ------------------------------------
# day: 1493, episode: 60
# begin_total_asset: 100000000.00
# end_total_asset: 203220380.20
# total_reward: 103220380.20
# total_cost: 5578219.80
# total_trades: 27
# Sharpe: 0.950
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 17700     |
# |    time_elapsed       | 254       |
# |    total_timesteps    | 88500     |
# | train/                |           |
# |    entropy_loss       | -3        |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17699     |
# |    policy_loss        | -0.00134  |
# |    std                | 4.88      |
# |    value_loss         | 2.81e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 17800    |
# |    time_elapsed       | 256      |
# |    total_timesteps    | 89000    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | -0.0979  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17799    |
# |    policy_loss        | -35      |
# |    std                | 4.92     |
# |    value_loss         | 149      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 17900     |
# |    time_elapsed       | 257       |
# |    total_timesteps    | 89500     |
# | train/                |           |
# |    entropy_loss       | -3.02     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17899     |
# |    policy_loss        | 0.0122    |
# |    std                | 4.96      |
# |    value_loss         | 2.24e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 18000     |
# |    time_elapsed       | 259       |
# |    total_timesteps    | 90000     |
# | train/                |           |
# |    entropy_loss       | -3.02     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17999     |
# |    policy_loss        | -256      |
# |    std                | 4.97      |
# |    value_loss         | 1.24e+04  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 18100    |
# |    time_elapsed       | 260      |
# |    total_timesteps    | 90500    |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | -70.6    |
# |    std                | 4.95     |
# |    value_loss         | 2.98e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 18200     |
# |    time_elapsed       | 261       |
# |    total_timesteps    | 91000     |
# | train/                |           |
# |    entropy_loss       | -3.01     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18199     |
# |    policy_loss        | -2.56e+03 |
# |    std                | 4.92      |
# |    value_loss         | 8.94e+05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 18300    |
# |    time_elapsed       | 263      |
# |    total_timesteps    | 91500    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | -165     |
# |    std                | 4.92     |
# |    value_loss         | 4.44e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 18400     |
# |    time_elapsed       | 264       |
# |    total_timesteps    | 92000     |
# | train/                |           |
# |    entropy_loss       | -3.01     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18399     |
# |    policy_loss        | -0.000198 |
# |    std                | 4.9       |
# |    value_loss         | 6.19e-09  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 18500    |
# |    time_elapsed       | 266      |
# |    total_timesteps    | 92500    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18499    |
# |    policy_loss        | 0.00814  |
# |    std                | 4.93     |
# |    value_loss         | 8e-06    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 18600     |
# |    time_elapsed       | 267       |
# |    total_timesteps    | 93000     |
# | train/                |           |
# |    entropy_loss       | -3.03     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18599     |
# |    policy_loss        | -1.03e-07 |
# |    std                | 5.01      |
# |    value_loss         | 2.98e-16  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 18700     |
# |    time_elapsed       | 269       |
# |    total_timesteps    | 93500     |
# | train/                |           |
# |    entropy_loss       | -3.06     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18699     |
# |    policy_loss        | -1.12e-07 |
# |    std                | 5.14      |
# |    value_loss         | 2.98e-16  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 18800     |
# |    time_elapsed       | 270       |
# |    total_timesteps    | 94000     |
# | train/                |           |
# |    entropy_loss       | -3.08     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18799     |
# |    policy_loss        | -8.78e-06 |
# |    std                | 5.27      |
# |    value_loss         | 8.41e-12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 18900     |
# |    time_elapsed       | 272       |
# |    total_timesteps    | 94500     |
# | train/                |           |
# |    entropy_loss       | -3.09     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18899     |
# |    policy_loss        | -0.000874 |
# |    std                | 5.32      |
# |    value_loss         | 1.12e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 19000    |
# |    time_elapsed       | 273      |
# |    total_timesteps    | 95000    |
# | train/                |          |
# |    entropy_loss       | -3.1     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18999    |
# |    policy_loss        | 0.00839  |
# |    std                | 5.38     |
# |    value_loss         | 8.73e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 19100    |
# |    time_elapsed       | 274      |
# |    total_timesteps    | 95500    |
# | train/                |          |
# |    entropy_loss       | -3.1     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19099    |
# |    policy_loss        | 0.0164   |
# |    std                | 5.36     |
# |    value_loss         | 3.65e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 19200    |
# |    time_elapsed       | 276      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -3.11    |
# |    explained_variance | 0.0485   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19199    |
# |    policy_loss        | 159      |
# |    std                | 5.44     |
# |    value_loss         | 2.59e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 19300    |
# |    time_elapsed       | 277      |
# |    total_timesteps    | 96500    |
# | train/                |          |
# |    entropy_loss       | -3.12    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | 0.00399  |
# |    std                | 5.51     |
# |    value_loss         | 2.28e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 19400    |
# |    time_elapsed       | 279      |
# |    total_timesteps    | 97000    |
# | train/                |          |
# |    entropy_loss       | -3.14    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | 2.58e-05 |
# |    std                | 5.59     |
# |    value_loss         | 7.57e-11 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 19500    |
# |    time_elapsed       | 280      |
# |    total_timesteps    | 97500    |
# | train/                |          |
# |    entropy_loss       | -3.15    |
# |    explained_variance | 0.00365  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19499    |
# |    policy_loss        | 429      |
# |    std                | 5.68     |
# |    value_loss         | 3.49e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 19600    |
# |    time_elapsed       | 282      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -3.17    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | 1.17e+03 |
# |    std                | 5.76     |
# |    value_loss         | 1.49e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 19700    |
# |    time_elapsed       | 283      |
# |    total_timesteps    | 98500    |
# | train/                |          |
# |    entropy_loss       | -3.16    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19699    |
# |    policy_loss        | 0.000124 |
# |    std                | 5.71     |
# |    value_loss         | 1.92e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 19800    |
# |    time_elapsed       | 284      |
# |    total_timesteps    | 99000    |
# | train/                |          |
# |    entropy_loss       | -3.16    |
# |    explained_variance | 0.00693  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19799    |
# |    policy_loss        | 73.2     |
# |    std                | 5.71     |
# |    value_loss         | 1.88e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 19900     |
# |    time_elapsed       | 286       |
# |    total_timesteps    | 99500     |
# | train/                |           |
# |    entropy_loss       | -3.16     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19899     |
# |    policy_loss        | -0.00693  |
# |    std                | 5.72      |
# |    value_loss         | 6.87e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 20000    |
# |    time_elapsed       | 287      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -3.17    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19999    |
# |    policy_loss        | -0.00478 |
# |    std                | 5.78     |
# |    value_loss         | 2.05e-06 |
# ------------------------------------

# %% [markdown]
# ### PPO model

# %%
print("==============Model Training===========")
now = datetime.datetime.now().strftime("%Y%m%d-%Hh%M")

model_ppo = agent.get_model("ppo")
trained_ppo = agent.train_model(
    model=model_ppo, tb_log_name="ppo", total_timesteps=100000
)
# Out:
# ==============Model Training===========
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_1
# -----------------------------
# | time/              |      |
# |    fps             | 399  |
# |    iterations      | 1    |
# |    time_elapsed    | 5    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0013894257 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000149    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.28e+04     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000458    |
# |    std                  | 0.995        |
# |    value_loss           | 6.5e+04      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.003556233 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.00138     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.08e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00288    |
# |    std                  | 0.995       |
# |    value_loss           | 2.99e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 4            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0037963665 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0019       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.96e+04     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00234     |
# |    std                  | 0.997        |
# |    value_loss           | 1.12e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 5            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0028980915 |
# |    clip_fraction        | 0.00894      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.00423      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.99e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00112     |
# |    std                  | 0.975        |
# |    value_loss           | 3.09e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 6           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004384322 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -0.0079     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.95e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00352    |
# |    std                  | 0.983       |
# |    value_loss           | 3.12e+04    |
# -----------------------------------------
# day: 1493, episode: 10
# begin_total_asset: 100000000.00
# end_total_asset: 68101708.85
# total_reward: -31898291.15
# total_cost: 90699591.15
# total_trades: 683
# Sharpe: -0.364
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 7             |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00018260145 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | -0.000186     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.27e+04      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -2.22e-05     |
# |    std                  | 0.981         |
# |    value_loss           | 5.37e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 8            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0025122764 |
# |    clip_fraction        | 0.00083      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.00283     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.28e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -1.65e-05    |
# |    std                  | 0.984        |
# |    value_loss           | 7.59e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 9            |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0002040308 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.000524    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.14e+04     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -9e-05       |
# |    std                  | 0.981        |
# |    value_loss           | 8.79e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 10            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00013444613 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | -0.00124      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.07e+04      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -5.31e-05     |
# |    std                  | 0.981         |
# |    value_loss           | 1.19e+05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 11          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006313922 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -0.000872   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.99e+04    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00408    |
# |    std                  | 0.981       |
# |    value_loss           | 5.5e+04     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 12           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0016960476 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.00123     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.95e+04     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00132     |
# |    std                  | 0.984        |
# |    value_loss           | 8.31e+04     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 381        |
# |    iterations           | 13         |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00490765 |
# |    clip_fraction        | 0.0173     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | -0.00219   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.28e+03   |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -4.91e-05  |
# |    std                  | 0.978      |
# |    value_loss           | 3.28e+04   |
# ----------------------------------------
# day: 1493, episode: 20
# begin_total_asset: 100000000.00
# end_total_asset: 21220734.00
# total_reward: -78779266.00
# total_cost: 26358666.00
# total_trades: 685
# Sharpe: -0.437
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 14           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0018798299 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.000132    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.74e+04     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00074     |
# |    std                  | 0.972        |
# |    value_loss           | 5.44e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 15           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0018051815 |
# |    clip_fraction        | 0.00845      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00135      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.74e+04     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000188    |
# |    std                  | 0.966        |
# |    value_loss           | 6.1e+04      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 16           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0057119033 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00612     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.37e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00256     |
# |    std                  | 0.963        |
# |    value_loss           | 1.06e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 17          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003088047 |
# |    clip_fraction        | 0.0062      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00142    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.88e+04    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.000228    |
# |    std                  | 0.96        |
# |    value_loss           | 1.02e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 18           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0053377007 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00026     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.1e+04      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00245     |
# |    std                  | 0.953        |
# |    value_loss           | 7.16e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 19          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004667283 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00372     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.02e+04    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00306    |
# |    std                  | 0.943       |
# |    value_loss           | 7.92e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 20           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0054929852 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000631    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.2e+04      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0021      |
# |    std                  | 0.934        |
# |    value_loss           | 4.52e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 21            |
# |    time_elapsed         | 112           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00023896224 |
# |    clip_fraction        | 0.000293      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 0.000535      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.02e+05      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000549     |
# |    std                  | 0.934         |
# |    value_loss           | 3e+05         |
# -------------------------------------------
# day: 1493, episode: 30
# begin_total_asset: 100000000.00
# end_total_asset: 88149340.15
# total_reward: -11850659.85
# total_cost: 113148959.85
# total_trades: 713
# Sharpe: -0.028
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 22           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0013332677 |
# |    clip_fraction        | 0.00776      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00026     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.39e+04     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00136     |
# |    std                  | 0.932        |
# |    value_loss           | 1.5e+05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 23           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0030380231 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00195     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.41e+04     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 7.61e-05     |
# |    std                  | 0.93         |
# |    value_loss           | 1.95e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 24          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004371303 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00241    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.17e+04    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00108    |
# |    std                  | 0.925       |
# |    value_loss           | 1.04e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 25           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0021065134 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.000409    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.76e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00108     |
# |    std                  | 0.925        |
# |    value_loss           | 8.34e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 26           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0028588937 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000929     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.98e+04     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.000938     |
# |    std                  | 0.931        |
# |    value_loss           | 1.11e+05     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 381        |
# |    iterations           | 27         |
# |    time_elapsed         | 144        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00553708 |
# |    clip_fraction        | 0.0468     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | -0.000722  |
# |    learning_rate        | 0.00025    |
# |    loss                 | 2.68e+04   |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00513   |
# |    std                  | 0.936      |
# |    value_loss           | 4.07e+04   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 28           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0019500535 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00162     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.3e+04      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 0.941        |
# |    value_loss           | 7.03e+04     |
# ------------------------------------------
# day: 1493, episode: 40
# begin_total_asset: 100000000.00
# end_total_asset: 27534295.30
# total_reward: -72465704.70
# total_cost: 30644804.70
# total_trades: 656
# Sharpe: -0.304
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 29           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0014485909 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.0022      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.81e+04     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00095     |
# |    std                  | 0.945        |
# |    value_loss           | 1.12e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 30           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0030332373 |
# |    clip_fraction        | 0.00981      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.002        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.7e+04      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000486    |
# |    std                  | 0.947        |
# |    value_loss           | 5.5e+04      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 31          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.001659737 |
# |    clip_fraction        | 0.00566     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00228     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.16e+04    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00111    |
# |    std                  | 0.945       |
# |    value_loss           | 1.58e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 32           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0036305606 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00188      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.37e+04     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000569    |
# |    std                  | 0.939        |
# |    value_loss           | 1.66e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 33           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0005754599 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00332     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.84e+04     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00078     |
# |    std                  | 0.939        |
# |    value_loss           | 1.64e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 34           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0046160584 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00165     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.42e+04     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000908    |
# |    std                  | 0.945        |
# |    value_loss           | 7.13e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 35           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0034520247 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000746    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.31e+04     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000635    |
# |    std                  | 0.938        |
# |    value_loss           | 8.15e+04     |
# ------------------------------------------
# day: 1493, episode: 50
# begin_total_asset: 100000000.00
# end_total_asset: 64955728.80
# total_reward: -35044271.20
# total_cost: 76717171.20
# total_trades: 561
# Sharpe: -0.350
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 36           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0048392117 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00278      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.7e+04      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00311     |
# |    std                  | 0.933        |
# |    value_loss           | 1.07e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 37          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004397099 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0021      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.29e+04    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00247    |
# |    std                  | 0.935       |
# |    value_loss           | 8.99e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 38           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0036888062 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00286      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.99e+04     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00426     |
# |    std                  | 0.935        |
# |    value_loss           | 9.86e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 39            |
# |    time_elapsed         | 208           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00089519995 |
# |    clip_fraction        | 0.00464       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 0.00263       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.27e+05      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000541     |
# |    std                  | 0.926         |
# |    value_loss           | 2.29e+05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 40          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007811589 |
# |    clip_fraction        | 0.02        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0185     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.05e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00151    |
# |    std                  | 0.905       |
# |    value_loss           | 3.08e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 41          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010137577 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.00818    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.24e+04    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00158     |
# |    std                  | 0.898       |
# |    value_loss           | 9.79e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 42           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0015550284 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.00173      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.6e+03      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 0.896        |
# |    value_loss           | 6.36e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 43            |
# |    time_elapsed         | 230           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00068990234 |
# |    clip_fraction        | 0.019         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | 0.00177       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.9e+04       |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000875     |
# |    std                  | 0.892         |
# |    value_loss           | 5.33e+04      |
# -------------------------------------------
# day: 1493, episode: 60
# begin_total_asset: 100000000.00
# end_total_asset: 96622425.20
# total_reward: -3377574.80
# total_cost: 71983174.80
# total_trades: 437
# Sharpe: 0.050
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 44            |
# |    time_elapsed         | 235           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00087988307 |
# |    clip_fraction        | 0.00356       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.3          |
# |    explained_variance   | -0.00449      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 9.36e+04      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000882     |
# |    std                  | 0.879         |
# |    value_loss           | 1.54e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 45           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0036493845 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.0011      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.54e+04     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00277     |
# |    std                  | 0.881        |
# |    value_loss           | 5.05e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 46           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0030931493 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.000726    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.87e+04     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00301     |
# |    std                  | 0.872        |
# |    value_loss           | 1.5e+05      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 47          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005004404 |
# |    clip_fraction        | 0.0446      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.00115    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.01e+04    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.000612   |
# |    std                  | 0.868       |
# |    value_loss           | 1.13e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 48           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0022041555 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -0.00217     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.24e+04     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0014      |
# |    std                  | 0.847        |
# |    value_loss           | 5.07e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 49            |
# |    time_elapsed         | 262           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00059622875 |
# |    clip_fraction        | 0.0215        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.25         |
# |    explained_variance   | 0.00143       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.27e+04      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -5.17e-05     |
# |    std                  | 0.848         |
# |    value_loss           | 1.24e+05      |
# -------------------------------------------

# %% [markdown]
# ### DDPG model

# %%
print("==============Model Training===========")
now = datetime.datetime.now().strftime("%Y%m%d-%Hh%M")

model_ddpg = agent.get_model("ddpg")
trained_ddpg = agent.train_model(
    model=model_ddpg, tb_log_name="ppo", total_timesteps=50000
)

# %% [markdown]
# ### TD3 model

# %%
print("==============Model Training===========")
now = datetime.datetime.now().strftime("%Y%m%d-%Hh%M")

model_td3 = agent.get_model("td3")
trained_td3 = agent.train_model(
    model=model_td3, tb_log_name="td3", total_timesteps=30000
)
# Out:
# ==============Model Training===========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cuda device
# Logging to tensorboard_log/td3/td3_1
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 158      |
# |    time_elapsed    | 37       |
# |    total timesteps | 5976     |
# | train/             |          |
# |    actor_loss      | 3.97e+04 |
# |    critic_loss     | 2.6e+09  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4482     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 143      |
# |    time_elapsed    | 83       |
# |    total timesteps | 11952    |
# | train/             |          |
# |    actor_loss      | 2.98e+04 |
# |    critic_loss     | 1.99e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10458    |
# ---------------------------------
# day: 1493, episode: 10
# begin_total_asset: 100000000.00
# end_total_asset: 92717384.20
# total_reward: -7282615.80
# total_cost: 232615.80
# total_trades: 3
# Sharpe: 0.292
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 139      |
# |    time_elapsed    | 128      |
# |    total timesteps | 17928    |
# | train/             |          |
# |    actor_loss      | 2.53e+04 |
# |    critic_loss     | 2.11e+08 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16434    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 136      |
# |    time_elapsed    | 175      |
# |    total timesteps | 23904    |
# | train/             |          |
# |    actor_loss      | 2.25e+04 |
# |    critic_loss     | 2.84e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22410    |
# ---------------------------------
# day: 1493, episode: 20
# begin_total_asset: 100000000.00
# end_total_asset: 92717384.20
# total_reward: -7282615.80
# total_cost: 232615.80
# total_trades: 3
# Sharpe: 0.292
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 135      |
# |    time_elapsed    | 220      |
# |    total timesteps | 29880    |
# | train/             |          |
# |    actor_loss      | 1.95e+04 |
# |    critic_loss     | 2.46e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28386    |
# ---------------------------------

# %% [markdown]
# ### Ensemble Agent

# %% [markdown]
# Ensemble agent contains 3 DRL algorithms: A2C, PPO, DDPG
#
# `class DRLEnsembleAgent` has been adjusted by original repo (AI4Finance-LLC) for suitable with ensemble method.

# %%
# env_esemble_kwargs
train_period = [config.START_DATE, config.START_TRADE_DATE]
val_test_period = [config.START_TRADE_DATE, config.END_DATE]

env_ensemble_kwargs = {
        "df": processed_full,
        "train_period": train_period,
        "val_test_period": val_test_period,
        "rebalance_window": 63,
        "validation_window": 63,
        "stock_dim": stock_dimension,
        "hmax": 50000,
        "initial_amount": 100000000,
        "buy_cost_pct": 0.0015,
        "sell_cost_pct": 0.0015,
        "reward_scaling": 1e-4,
        "state_space": state_space,
        "action_space": stock_dimension,
        "tech_indicator_list": config.TECHNICAL_INDICATORS_LIST,
        "print_verbosity": 10
    }

timesteps_dict = {
        'a2c': 100000,
        'ppo': 100000,
        'ddpg': 50000
    }

# %%
# Initialize Ensemble Agent
ensembleAgent = DRLEnsembleAgent(**env_ensemble_kwargs)

# %%
# Train 
print("==============Model Training===========")
now = datetime.datetime.now().strftime("%Y%m%d-%Hh%M")
ensemble_model = ensembleAgent.run_ensemble_strategy(
    config.A2C_PARAMS, config.PPO_PARAMS, config.DDPG_PARAMS, timesteps_dict=timesteps_dict)
ensemble_model.to_csv(
    "./" + config.RESULTS_DIR + "/df_ensemble_summary" + now + ".csv")

# %% [markdown]
# ## Model trading

# %% [markdown]
# **Đổi model trading thành model trading vừa mới được train ở phía trên**

# %%
print("==============Start Trading===========")
e_trade_gym = StockTradingEnv(
    df=trade, turbulence_threshold=250, **env_kwargs)

df_account_value, df_actions = DRLAgent.DRL_prediction(
    model=trained_ddpg, environment=e_trade_gym                          # Đổi model
)
df_account_value.to_csv(
    "./" + config.RESULTS_DIR + "/df_account_value_" + now + ".csv"
)
df_actions.to_csv("./" + config.RESULTS_DIR +
                    "/df_actions_" + now + ".csv")
# Out:
# ==============Start Trading===========
# hit end!

# %% [markdown]
# ## Backtest

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime("%Y%m%d-%Hh%M")
perf_stats_all = backtest_stats(df_account_value)              # Đổi lại thành df_account_value
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv("./" + config.RESULTS_DIR +
                        "/perf_stats_all_" + now + ".csv")
